# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.randn(4,3),index=['a','c','d','f'],columns=['one','two','three'])
df=df.reindex(['a','b','c','d','e','f'])
print("Original Dataframe with NaN\n",df)
print("\n")
print("Dropped DataFrame\n",df.dropna())
print("\n")
# Out:
# Original Dataframe with NaN
#          one       two     three
# a  0.952256  0.547644 -1.436746
# b       NaN       NaN       NaN
# c -0.567169 -0.539071  0.971352
# d  0.494484  0.491558  0.414216
# e       NaN       NaN       NaN
# f -0.801682 -0.772939 -2.737995
#
#
# Dropped DataFrame
#          one       two     three
# a  0.952256  0.547644 -1.436746
# c -0.567169 -0.539071  0.971352
# d  0.494484  0.491558  0.414216
# f -0.801682 -0.772939 -2.737995

# %%
df=pd.DataFrame(np.random.randn(4,3),index=['a','c','d','f'],columns=['one','two','three'])
df=df.reindex(['a','b','c'])
print("Original DataFrame:\n",df)
print("\n")
print("NaN replaced with '0':\n")
print(df.fillna(0))
# Out:
# Original DataFrame:
#          one       two     three
# a  1.410709 -0.115393 -0.520910
# b       NaN       NaN       NaN
# c -1.288766  0.059470 -0.968772
#
#
# NaN rplaced with '0':
#
#         one       two     three
# a  1.410709 -0.115393 -0.520910
# b  0.000000  0.000000  0.000000
# c -1.288766  0.059470 -0.968772

# %%
df=pd.DataFrame({'one':[10,20,80,40,50],'two':[60,70,80,0,10]})
print("Original Dataframe:\n",df)
print("\n DataFrame with replaced values:\n")
print(df.replace({10:5,80:3}))
# Out:
# Original Dataframe:
#     one  two
# 0   10   60
# 1   20   70
# 2   80   80
# 3   40    0
# 4   50   10
#
#  DataFrame with replaced values:
#
#    one  two
# 0    5   60
# 1   20   70
# 2    3    3
# 3   40    0
# 4   50    5

# %%
df=pd.DataFrame(np.random.randn(4,3),index=['a','c','d','f'],columns=['one','two','three'])
df=df.reindex(['a','b','c','d','e','f'])
print("Original Dataframe:\n",df)
print("\nNaN-Filled with Background values:\n")
print(df.fillna(method='bfill'))
# Out:
# Original Dataframe:
#          one       two     three
# a -0.101332 -0.231292  1.427601
# b       NaN       NaN       NaN
# c -0.370021 -0.184275  0.122455
# d  0.826477 -1.164301 -0.242275
# e       NaN       NaN       NaN
# f  0.358349  0.955077 -0.886343
#
# NaN-Filled with Background values:
#
#         one       two     three
# a -0.101332 -0.231292  1.427601
# b -0.370021 -0.184275  0.122455
# c -0.370021 -0.184275  0.122455
# d  0.826477 -1.164301 -0.242275
# e  0.358349  0.955077 -0.886343
# f  0.358349  0.955077 -0.886343
# /tmp/ipython-input-1498132536.py:5: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   print(df.fillna(method='bfill'))

# %%
df=pd.DataFrame(np.random.randn(4,3),index=['a','c','d','f'],columns=['one','two','three'])
df=df.reindex(['a','b','c','d','e','f'])
print("Original Dataframe:\n",df)
print("\nNan-with True fill:\n")
print(df['one'].isnull())
# Out:
# Original Dataframe:
#          one       two     three
# a  1.317096 -0.511677 -0.249475
# b       NaN       NaN       NaN
# c -0.648836 -0.980479  1.286556
# d  1.790424 -1.109250  0.374100
# e       NaN       NaN       NaN
# f -0.729309  0.852968 -0.119496
#
# Nan-with True fill:
#
# a    False
# b     True
# c    False
# d    False
# e     True
# f    False
# Name: one, dtype: bool
