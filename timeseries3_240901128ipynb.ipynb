# %% [markdown]
# <a href="https://colab.research.google.com/github/Yogesh240901128/ppml/blob/main/timeseries3_240901128ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from datetime import datetime

#create a date variable that contains the dates
dates = [datetime(2011, 1, 2),
datetime(2011, 1, 5),
datetime(2011, 1, 7),
datetime(2011, 1, 8),
datetime(2011, 1, 10),
datetime(2011, 1, 12)]

#with this date object, create a series
ts = pd.Series(np.random.randn(6), index=dates)
print("Date Index \n",ts)
# Out:
# Date Index
#  2011-01-02    1.086322
# 2011-01-05    0.845398
# 2011-01-07   -2.650198
# 2011-01-08   -0.480380
# 2011-01-10    0.611036
# 2011-01-12    1.260212
# dtype: float64

# %%
print("\nDate Index alone from the series: \n",ts.index)
# Out:
# Date Index alone from the series:
#  DatetimeIndex(['2011-01-02', '2011-01-05', '2011-01-07', '2011-01-08',
#                '2011-01-10', '2011-01-12'],
#               dtype='datetime64[ns]', freq=None)

# %%
stamp=ts.index[2]
print("\nSecond index:\n", stamp)
# Out:
# Second index:
#  2011-01-07 00:00:00

# %%
#play like a ball with long-times series
longer_ts=pd.Series(np.random.randn(1000),
index=pd.date_range("2000-01-01",periods=1000))
print("\nDaterange up to 1000 days:\n",longer_ts)
# Out:
# Daterange up to 1000 days:
#  2000-01-01    1.374131
# 2000-01-02    1.716345
# 2000-01-03    0.880176
# 2000-01-04    1.217848
# 2000-01-05    0.489622
#                 ...
# 2002-09-22    0.323555
# 2002-09-23    0.409806
# 2002-09-24   -0.480203
# 2002-09-25   -0.526657
# 2002-09-26   -0.734390
# Freq: D, Length: 1000, dtype: float64

# %%
print("\nDate range-2001 year:\n", longer_ts["2001"])
# Out:
# Date range-2001 year:
#  2001-01-01    2.392652
# 2001-01-02    0.393801
# 2001-01-03   -0.551804
# 2001-01-04   -1.872031
# 2001-01-05    2.154985
#                 ...
# 2001-12-27    0.225010
# 2001-12-28   -0.688827
# 2001-12-29    2.753106
# 2001-12-30   -0.843874
# 2001-12-31   -0.565933
# Freq: D, Length: 365, dtype: float64

# %%
print("\nDate range-05 month 2001 year:\n", longer_ts["2001-05"])
# Out:
# Date range-05 month 2001 year:
#  2001-05-01   -1.209304
# 2001-05-02    0.498990
# 2001-05-03   -0.499680
# 2001-05-04    1.432594
# 2001-05-05    0.347684
# 2001-05-06   -0.222545
# 2001-05-07   -0.443221
# 2001-05-08    2.157317
# 2001-05-09   -1.131196
# 2001-05-10    0.001618
# 2001-05-11   -0.236210
# 2001-05-12   -0.697427
# 2001-05-13   -0.473189
# 2001-05-14    1.363282
# 2001-05-15    0.430015
# 2001-05-16    0.233541
# 2001-05-17    0.160676
# 2001-05-18    0.806919
# 2001-05-19    0.679985
# 2001-05-20   -0.271101
# 2001-05-21    0.466717
# 2001-05-22    1.820127
# 2001-05-23   -1.636898
# 2001-05-24    0.491107
# 2001-05-25    1.407528
# 2001-05-26    0.682905
# 2001-05-27    0.265896
# 2001-05-28   -0.884064
# 2001-05-29    1.578018
# 2001-05-30   -1.429955
# 2001-05-31   -1.393958
# Freq: D, dtype: float64

# %%
print("\nDate range-first few dates in 2000 year:\n",longer_ts["2000"].head())
# Out:
# Date range-first few dates in 2000 year:
#  2000-01-01    1.374131
# 2000-01-02    1.716345
# 2000-01-03    0.880176
# 2000-01-04    1.217848
# 2000-01-05    0.489622
# Freq: D, dtype: float64

# %%
print("\nDate range-first 15 dates in 02 month 2001 year:\n",longer_ts["2000-02"].head(15))
# Out:
# Date range-first 15 dates in 02 month 2001 year:
#  2000-02-01    0.655681
# 2000-02-02    0.694283
# 2000-02-03   -0.037144
# 2000-02-04   -1.449065
# 2000-02-05    0.612692
# 2000-02-06   -0.024683
# 2000-02-07    1.689834
# 2000-02-08   -0.774160
# 2000-02-09    1.060870
# 2000-02-10   -0.143390
# 2000-02-11   -0.092210
# 2000-02-12    1.228039
# 2000-02-13   -0.441380
# 2000-02-14    1.509207
# 2000-02-15   -1.243684
# Freq: D, dtype: float64

# %%
print("\nDate range-rom 26-9-2001:\n",longer_ts[datetime(2000,9,26):])
# Out:
# Date range-rom 26-9-2001:
#  2000-09-26   -0.245698
# 2000-09-27    0.343111
# 2000-09-28   -0.060798
# 2000-09-29   -0.556542
# 2000-09-30   -0.121495
#                 ...
# 2002-09-22    0.323555
# 2002-09-23    0.409806
# 2002-09-24   -0.480203
# 2002-09-25   -0.526657
# 2002-09-26   -0.734390
# Freq: D, Length: 731, dtype: float64
