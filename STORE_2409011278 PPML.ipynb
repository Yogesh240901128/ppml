# %% [markdown]
# <a href="https://colab.research.google.com/github/HIMAL98/ppml/blob/main/STORE_240901127_PPML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]],index=['one','two','three'],columns=['a','b','c'])
print(df)

print("Taking the inputfrom dataframe and storing in the excel file")
df.to_excel('excel_file_1.xlsx',sheet_name='new_sheet_name')

#Second Dataframe input to another Excel file
d= pd.DataFrame([[110,210,310],[12,220,320],[310,320,330]],index=['four','five','six'],columns=['a','b','c'])
d.to_excel('excel_file_2.xlsx',sheet_name='new_sheet_name')

#Merging two excel files inputinto third file
x=pd.read_excel('excel_file_1.xlsx')
y=pd.read_excel('excel_file_2.xlsx')
z=pd.concat([x,y])
z.to_excel('pandas_to_excel_merged.xlsx')

#Sorting the column values
df=z.sort_values(["a"])
print(df)
df.to_excel('excel_file_4_sorted.xlsx')



df=pd.read_excel('excel_file_4_sorted.xlsx')
print(df)
print(list(df))
print(format(len(df)))
# Out:
#        a  b  c
# one    1  2  3
# two    4  5  6
# three  7  8  9
# Taking the inputfrom dataframe and storing in the excel file
#   Unnamed: 0    a    b    c
# 0        one    1    2    3
# 1        two    4    5    6
# 2      three    7    8    9
# 1       five   12  220  320
# 0       four  110  210  310
# 2        six  310  320  330
#    Unnamed: 0.1 Unnamed: 0    a    b    c
# 0             0        one    1    2    3
# 1             1        two    4    5    6
# 2             2      three    7    8    9
# 3             1       five   12  220  320
# 4             0       four  110  210  310
# 5             2        six  310  320  330
# ['Unnamed: 0.1', 'Unnamed: 0', 'a', 'b', 'c']
# 6
