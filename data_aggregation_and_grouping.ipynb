# %% [markdown]
# <a href="https://colab.research.google.com/github/Yogesh240901128/ppml/blob/main/data_aggregation_and_grouping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame({'A':['sai','sai','subu','yuvi','rithi','subu'],'B':['one','one','three','one','three','three'],'C':np.random.randint(5,size=6),'D':np.random.randint(5,size=6),'E':np.random.randint(5,size=6)})
print("\nOriginal DataFrame\n",df)
# Out:
# Original DataFrame
#         A      B  C  D  E
# 0    sai    one  1  1  1
# 1    sai    one  3  0  0
# 2   subu  three  4  3  0
# 3   yuvi    one  4  0  4
# 4  rithi  three  1  0  2
# 5   subu  three  3  4  4

# %%
df1=df.groupby(['A','B'],as_index=False)['C'].sum()
print("\nOriginal DataFrame\n",df)
print("\nGroup by (multi-column): with one column sum\n",df1)
# Out:
# Original DataFrame
#         A      B  C  D  E
# 0    sai    one  1  1  1
# 1    sai    one  3  0  0
# 2   subu  three  4  3  0
# 3   yuvi    one  4  0  4
# 4  rithi  three  1  0  2
# 5   subu  three  3  4  4
#
# Group by (multi-column): with one column sum
#         A      B  C
# 0  rithi  three  1
# 1    sai    one  4
# 2   subu  three  7
# 3   yuvi    one  4

# %%
df2=df.groupby(['A','B'],as_index=False).sum()
print("\nOriginal DataFrame\n",df2)
print("\nGroup by (multi-column): with multi columns sum\n",df2)
# Out:
# Original DataFrame
#         A      B  C  D  E
# 0  rithi  three  1  0  2
# 1    sai    one  4  1  1
# 2   subu  three  7  7  4
# 3   yuvi    one  4  0  4
#
# Group by (multi-column): with multi columns sum
#         A      B  C  D  E
# 0  rithi  three  1  0  2
# 1    sai    one  4  1  1
# 2   subu  three  7  7  4
# 3   yuvi    one  4  0  4

# %%
df3=df.groupby(['A','B'],as_index=False)['C'].agg('sum')
print("\nOriginal DataFrame\n",df3)
print("\nCombined Groupby and Aggregate function\n",df3)
# Out:
# Original DataFrame
#         A      B  C
# 0  rithi  three  1
# 1    sai    one  4
# 2   subu  three  7
# 3   yuvi    one  4
#
# Combined Groupby and Aggregate function
#         A      B  C
# 0  rithi  three  1
# 1    sai    one  4
# 2   subu  three  7
# 3   yuvi    one  4

# %%
df4=(df.groupby)
